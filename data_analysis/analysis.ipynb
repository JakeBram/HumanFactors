# %% [markdown]
# Importing Dataframe and Math Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Reading one of my data files, lets see what we've got right now.

# %%
jbt23 = pd.read_csv('Project Data/JakeData/RTtr1Jake_20-30dis.csv')
jbt23.head()
# Out:
#    Distance  Score
# 0        58  229.0
# 1        56    NaN
# 2        48    NaN
# 3        48    NaN
# 4        34    NaN

# %% [markdown]
# Right. Thats all the distances. We can make a series with the average, the score, and add it to a main dataframe.

# %%
avg_distance = (np.average(jbt23['Distance']))
score = np.max(jbt23['Score'])
print(score)
# Out:
# 229.0

# %% [markdown]
# Above we got the average score, now lets make a row for our dataframe.

# %%
df = pd.read_csv('Project Data/dummy.csv')
list_row = ['Jake', 'Reaction Time', '20-30', 0, avg_distance, score, 273, -1]

# %% [markdown]
# And replace the dummy row with real data.

# %%
df.loc[len(df)] = list_row
df = df.drop(df.index[0])
df = df.reset_index(drop=True)
df.head()
# Out:
#   Subject           Task Threshold  ThresEncode  ObservedDistance  Score  \
# 0    Jake  Reaction Time     20-30            0         31.403846  229.0
#
#    AverageScore  Negativity
# 0           273          -1

# %% [markdown]
# Repeat for all data, the evaluate.
#
# Average Scores:
# Reaction Time - 273,
# Aim - 400,
# Typing - 40,

# %%
jba23 = pd.read_csv('Project Data/JakeData/aim20-30.csv')
avg_distance = (np.average(jba23['Distance']))
score = np.max(jba23['Score'])
jake_aim = ['Jake', 'Aim', '20-30',0, avg_distance, score, 400, -1]
df.loc[len(df)] = jake_aim
df.head()
# Out:
#   Subject           Task Threshold  ThresEncode  ObservedDistance  Score  \
# 0    Jake  Reaction Time     20-30            0         31.403846  229.0
# 1    Jake            Aim     20-30            0         29.962963  556.0
#
#    AverageScore  Negativity
# 0           273          -1
# 1           400          -1

# %%
this_file = pd.read_csv('Project Data/JakeData/aim50-60.csv')
avg_distance = (np.average(this_file['Distance']))
score = np.max(this_file['Score'])
this_row = ['Jake', 'Aim', '50-60',1, avg_distance, score, 400, -1]
df.loc[len(df)] = this_row

this_file = pd.read_csv('Project Data/JakeData/RTtr1Jake_50-60dis.csv')
avg_distance = (np.average(this_file['Distance']))
score = np.max(this_file['Score'])
this_row = ['Jake', 'Reaction Time', '50-60',1, avg_distance, score, 273, -1]
df.loc[len(df)] = this_row

this_file = pd.read_csv('Project Data/JakeData/typ50-60.csv')
avg_distance = (np.average(this_file['Distance']))
score = np.max(this_file['Score'])
this_row = ['Jake', 'Typing', '50-60',1, avg_distance, score, 40, 1]
df.loc[len(df)] = this_row

this_file = pd.read_csv('Project Data/JakeData/typing20-30.csv')
avg_distance = (np.average(this_file['Distance']))
score = np.max(this_file['Score'])
this_row = ['Jake', 'Typing', '20-30',0, avg_distance, score, 40, 1]
df.loc[len(df)] = this_row

# %% [markdown]
# Yasha's Data

# %%
this_file = pd.read_csv('Project Data/YashaData/aimtrainer20-30.csv')
avg_distance = (np.average(this_file['Distance']))
score = np.max(this_file['Score'])
this_row = ['Yasha', 'Aim', '20-30',0, avg_distance, score, 400, -1]
df.loc[len(df)] = this_row

this_file = pd.read_csv('Project Data/YashaData/aimtrainer50-60.csv')
avg_distance = (np.average(this_file['Distance']))
score = np.max(this_file['Score'])
this_row = ['Yasha', 'Aim', '50-60', 1, avg_distance, score, 400, -1]
df.loc[len(df)] = this_row

this_file = pd.read_csv('Project Data/YashaData/reaction20-30.csv')
avg_distance = (np.average(this_file['Distance']))
score = np.max(this_file['Score'])
this_row = ['Yasha', 'Reaction Time', '20-30', 0, avg_distance, score, 273, -1]
df.loc[len(df)] = this_row

this_file = pd.read_csv('Project Data/YashaData/reaction50-60.csv')
avg_distance = (np.average(this_file['Distance']))
score = np.max(this_file['Score'])
this_row = ['Yasha', 'Reaction Time', '50-60', 1, avg_distance, score, 273, -1]
df.loc[len(df)] = this_row

this_file = pd.read_csv('Project Data/YashaData/typing20-30.csv')
avg_distance = (np.average(this_file['Distance']))
score = np.max(this_file['Score'])
this_row = ['Yasha', 'Typing', '20-30', 0, avg_distance, score, 40, 1]
df.loc[len(df)] = this_row

this_file = pd.read_csv('Project Data/YashaData/typing50-60.csv')
avg_distance = (np.average(this_file['Distance']))
score = np.max(this_file['Score'])
this_row = ['Yasha', 'Typing', '50-60', 1, avg_distance, score, 40, 1]
df.loc[len(df)] = this_row

# %% [markdown]
# Jerry Data

# %%
this_file = pd.read_csv('Project Data/JerryData/aim20-30.csv')
avg_distance = (np.average(this_file['Distance']))
score = np.max(this_file['Score'])
this_row = ['Jerry', 'Aim', '20-30', 0, avg_distance, score, 400, -1]
df.loc[len(df)] = this_row

this_file = pd.read_csv('Project Data/JerryData/aim50-60.csv')
avg_distance = (np.average(this_file['Distance']))
score = np.max(this_file['Score'])
this_row = ['Jerry', 'Aim', '50-60', 1, avg_distance, score, 400, -1]
df.loc[len(df)] = this_row

this_file = pd.read_csv('Project Data/JerryData/reaction20-30.csv')
avg_distance = (np.average(this_file['Distance']))
score = np.max(this_file['Score'])
this_row = ['Jerry', 'Reaction Time', '20-30', 0, avg_distance, score, 273, -1]
df.loc[len(df)] = this_row

this_file = pd.read_csv('Project Data/JerryData/reaction50-60.csv')
avg_distance = (np.average(this_file['Distance']))
score = np.max(this_file['Score'])
this_row = ['Jerry', 'Reaction Time', '50-60', 1, avg_distance, score, 273, -1]
df.loc[len(df)] = this_row

this_file = pd.read_csv('Project Data/JerryData/typing20-30.csv')
avg_distance = (np.average(this_file['Distance']))
score = np.max(this_file['Score'])
this_row = ['Jerry', 'Typing', '20-30', 0, avg_distance, score, 40, 1]
df.loc[len(df)] = this_row

this_file = pd.read_csv('Project Data/JerryData/typing50-60.csv')
avg_distance = (np.average(this_file['Distance']))
score = np.max(this_file['Score'])
this_row = ['Jerry', 'Typing', '50-60', 1, avg_distance, score, 40, 1]
df.loc[len(df)] = this_row

# %% [markdown]
# Johnathon Data

# %%
this_file = pd.read_csv('Project Data/JonathanData/aim20-30.csv')
avg_distance = (np.average(this_file['Distance']))
score = np.max(this_file['Score'])
this_row = ['Johnathon', 'Aim', '20-30', 0, avg_distance, score, 400, -1]
df.loc[len(df)] = this_row

this_file = pd.read_csv('Project Data/JonathanData/aim50-60.csv')
avg_distance = (np.average(this_file['Distance']))
score = np.max(this_file['Score'])
this_row = ['Johnathon', 'Aim', '50-60', 1, avg_distance, score, 400, -1]
df.loc[len(df)] = this_row

this_file = pd.read_csv('Project Data/JonathanData/reaction20-30.csv')
avg_distance = (np.average(this_file['Distance']))
score = np.max(this_file['Score'])
this_row = ['Johnathon', 'Reaction Time', '20-30', 0, avg_distance, score, 273, -1]
df.loc[len(df)] = this_row

this_file = pd.read_csv('Project Data/JonathanData/reaction50-60.csv')
avg_distance = (np.average(this_file['Distance']))
score = np.max(this_file['Score'])
this_row = ['Johnathon', 'Reaction Time', '50-60', 1, avg_distance, score, 273, -1]
df.loc[len(df)] = this_row

this_file = pd.read_csv('Project Data/JonathanData/typing20-30.csv')
avg_distance = (np.average(this_file['Distance']))
score = np.max(this_file['Score'])
this_row = ['Johnathon', 'Typing', '20-30', 0, avg_distance, score, 40, 1]
df.loc[len(df)] = this_row

this_file = pd.read_csv('Project Data/JonathanData/typing50-60.csv')
avg_distance = (np.average(this_file['Distance']))
score = np.max(this_file['Score'])
this_row = ['Johnathon', 'Typing', '50-60', 1, avg_distance, score, 40, 1]
df.loc[len(df)] = this_row

# %% [markdown]
# Lets see our DataFrame now.

# %%
print(df)
# Out:
#       Subject           Task Threshold  ThresEncode  ObservedDistance  Score  \
# 0        Jake  Reaction Time     20-30            0         31.403846  229.0
# 1        Jake            Aim     20-30            0         29.962963  556.0
# 2        Jake            Aim     50-60            1         57.480519  598.0
# 3        Jake  Reaction Time     50-60            1         56.853503  235.0
# 4        Jake         Typing     50-60            1         47.975000   47.0
# 5        Jake         Typing     20-30            0         25.625000   53.0
# 6       Yasha            Aim     20-30            0         32.421053  567.0
# 7       Yasha            Aim     50-60            1         53.923077  465.0
# 8       Yasha  Reaction Time     20-30            0         25.080000  318.0
# 9       Yasha  Reaction Time     50-60            1         57.641892  303.0
# 10      Yasha         Typing     20-30            0         28.789474   37.0
# ...

# %% [markdown]
# New Column for Analysis: % difference from average (absolute value)

# %%
df['ComparedToAverage'] = (df['Negativity']*(df['Score'] - df['AverageScore']))/df['AverageScore']


print(df['ComparedToAverage'])
# Out:
# 0     0.161172
# 1    -0.390000
# 2    -0.495000
# 3     0.139194
# 4     0.175000
# 5     0.325000
# 6    -0.417500
# 7    -0.162500
# 8    -0.164835
# 9    -0.109890
# 10   -0.075000
# 11   -0.125000
# 12   -0.450000
# 13   -0.332500
# 14    0.087912
# 15   -0.179487
# 16   -0.200000
# 17    0.050000
# 18   -0.207500
# 19   -0.225000
# 20    0.216117
# 21    0.183150
# 22    0.550000
# 23    0.550000
# Name: ComparedToAverage, dtype: float64

# %% [markdown]
# Lets see if we can see any relationships with the data we have

# %%
import seaborn as sns 
sns.set(style="darkgrid", color_codes=True)
g = sns.pairplot(df)
import matplotlib.pyplot as plt
plt.show()
#describe dataframe
df.describe()
# Out:
#        ThresEncode  ObservedDistance       Score  AverageScore  Negativity  \
# count    24.000000         24.000000   24.000000     24.000000   24.000000
# mean      0.500000         41.585907  280.625000    237.666667   -0.333333
# std       0.510754         13.037748  207.282586    152.284250    0.963087
# min       0.000000         25.080000   32.000000     40.000000   -1.000000
# 25%       0.000000         29.357032   59.750000     40.000000   -1.000000
# 50%       0.500000         40.198026  242.000000    273.000000   -1.000000
# 75%       1.000000         54.033852  484.750000    400.000000    1.000000
# max       1.000000         57.641892  598.000000    400.000000    1.000000
#
#        ComparedToAverage
# count          24.000000
# mean           -0.045694
# std             0.292237
# min            -0.495000
# 25%            -0.211875
# 50%            -0.117445
# 75%             0.164629
# max             0.550000

# %% [markdown]
# Now we can inspect individual cases, compare between instances.

# %%
jake = df[df["Subject"] == 'Jake'] 
print(jake)
# Out:
#   Subject           Task Threshold  ThresEncode  ObservedDistance  Score  \
# 0    Jake  Reaction Time     20-30            0         31.403846  229.0
# 1    Jake            Aim     20-30            0         29.962963  556.0
# 2    Jake            Aim     50-60            1         57.480519  598.0
# 3    Jake  Reaction Time     50-60            1         56.853503  235.0
# 4    Jake         Typing     50-60            1         47.975000   47.0
# 5    Jake         Typing     20-30            0         25.625000   53.0
#
#    AverageScore  Negativity  ComparedToAverage
# 0           273          -1           0.161172
# 1           400          -1          -0.390000
# 2           400          -1          -0.495000
# 3           273          -1           0.139194
# 4            40           1           0.175000
# 5            40           1           0.325000

# %%
sns.barplot(jake, x=jake['Task'], y=jake['ComparedToAverage'], hue=jake['Threshold'])
# Out:
# <Axes: xlabel='Task', ylabel='ComparedToAverage'>

# %%
yasha = df[df["Subject"] == 'Yasha'] 
sns.barplot(yasha, x=yasha['Task'], y=yasha['ComparedToAverage'], hue=yasha['Threshold'])
# Out:
# <Axes: xlabel='Task', ylabel='ComparedToAverage'>

# %%
Jerry = df[df["Subject"] == 'Jerry'] 
sns.barplot(Jerry, x=Jerry['Task'], y=Jerry['ComparedToAverage'], hue=Jerry['Threshold'])
# Out:
# <Axes: xlabel='Task', ylabel='ComparedToAverage'>

# %%
Johnathon = df[df["Subject"] == 'Johnathon'] 
sns.barplot(Johnathon, x=Johnathon['Task'], y=Johnathon['ComparedToAverage'], hue=Johnathon['Threshold'])
# Out:
# <Axes: xlabel='Task', ylabel='ComparedToAverage'>

# %% [markdown]
# The following lines of code are generating graphs for all scores in testing round 1. One barplot, one histogram.

# %%
sns.barplot(df, x=df['Task'], y=df['ComparedToAverage'], hue=df['Threshold'])
# Out:
# <Axes: xlabel='Task', ylabel='ComparedToAverage'>

# %%
sns.scatterplot(df, x=df['ThresEncode'], y=df['ComparedToAverage'], hue=df['Task'])
# Out:
# <Axes: xlabel='ThresEncode', ylabel='ComparedToAverage'>

# %% [markdown]
# Begining of Testing Round 2, T-Rex Game.

# %% [markdown]
# Create df

# %%
standard = pd.read_csv('Project Data/NoInternet/scores.csv')
distancekept = pd.read_csv('Project Data/NoInternet/distancekept.csv')
s1 = standard
s2 = distancekept
new_df = pd.DataFrame.append(standard, distancekept)
print(new_df)
# Out:
#     Scores  TrialType
# 0      644          0
# 1      985          0
# 2     1689          0
# 3     1487          0
# 4      331          0
# 5      294          0
# 6      278          0
# 7      348          0
# 8      178          0
# 9      369          0
# 10     347          0
# 11     216          0
# 12     455          0
# 13     250          0
# 14     217          0
# 0     1550          1
# 1      881          1
# 2     1209          1
# 3     1857          1
# 4     1497          1
# 5      252          1
# 6      247          1
# 7     1083          1
# 8      359          1
# 9      631          1
# 10     702          1
# 11     526          1
# 12     545          1
# 13     860          1
# 14    1056          1
# /var/folders/nb/dygfkftn1y9d153sh8z995fw0000gn/T/ipykernel_11722/654741377.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %% [markdown]
# Scatterplot for T-Rex Scores Below. 0 = no Arduino, 1 = Arduino support

# %%
sns.scatterplot(new_df, x=new_df['TrialType'], y=new_df['Scores'])
# Out:
# <Axes: xlabel='TrialType', ylabel='Scores'>

# %% [markdown]
# Barplot for T-Rex Scores Below. 0 = no Arduino, 1 = Arduino support

# %%
sns.barplot(new_df, x=new_df['TrialType'], y=new_df['Scores'])
# Out:
# <Axes: xlabel='TrialType', ylabel='Scores'>
